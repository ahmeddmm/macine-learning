# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe(include='object')
# Out:
# C:\Users\Abdel\AppData\Local\Temp\ipykernel_5548\87514550.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
df.describe(include='category')
# Out:
#         class deck
# count     891  203
# unique      3    7
# top     Third    C
# freq      491   59

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.198653
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.002245
# class          0.000000
# who            0.000000
# adult_male     0.000000
# deck           0.772166
# embark_town    0.002245
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
df.fillna({'age':df['age'].median()},inplace=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)
df.fillna({'embarked':df['embarked'].mode()[0]},inplace=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.drop(columns='embark_town',inplace=True)
df.drop(columns='deck',inplace=True)

# %%
df.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      0
# class         0
# who           0
# adult_male    0
# alive         0
# alone         0
# dtype: int64

# %%
df.drop(columns=['alive','sibsp','parch'],inplace=True)

# %%
df.drop(columns='class',inplace=True)
df.head()
# Out:
#    survived  pclass     sex   age     fare embarked    who  adult_male  alone
# 0         0       3    male  22.0   7.2500        S    man        True  False
# 1         1       1  female  38.0  71.2833        C  woman       False  False
# 2         1       3  female  26.0   7.9250        S  woman       False   True
# 3         1       1  female  35.0  53.1000        S  woman       False  False
# 4         0       3    male  35.0   8.0500        S    man        True   True

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.hist(figsize=(12,8))
plt.show()

# %%
sns.histplot(x='age',data=df,kde=True,bins=30)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(y='fare',data=df)
# Out:
# <Axes: ylabel='fare'>

# %%
sns.histplot(x='fare',data=df,bins=10)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
df['pclass'].value_counts()
# Out:
# pclass
# 3    400
# 1    210
# 2    164
# Name: count, dtype: int64

# %%
sex_dist=df['sex'].value_counts()

# %%
sns.barplot(x=sex_dist.index,y=sex_dist.values)
# Out:
# <Axes: xlabel='sex'>

# %%
sns.countplot(y='sex',data=df)
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
survived=df['survived'].value_counts()
survived
# Out:
# survived
# 0    455
# 1    319
# Name: count, dtype: int64

# %%
survived.plot(kind='pie')
# Out:
# <Axes: >

# %%
numirical_col=df.select_dtypes(include=np.number)
for col in numirical_col:
    sns.boxplot(y=df[col])
    plt.title(col)
    plt.show()

# %%
ranges=[0,2,12,18,35,60,100]
labels=['infant','child','teen','young','adult','senior']
df['age_group']=pd.cut(df['age'],bins=ranges,labels=labels)

# %%
df.tail()
# Out:
#      survived  pclass     sex   age    fare embarked    who  adult_male  \
# 885         0       3  female  39.0  29.125        Q  woman       False
# 887         1       1  female  19.0  30.000        S  woman       False
# 888         0       3  female  28.0  23.450        S  woman       False
# 889         1       1    male  26.0  30.000        C    man        True
# 890         0       3    male  32.0   7.750        Q    man        True
#
#      alone age_group
# 885  False     adult
# 887   True     young
# 888  False     young
# 889   True     young
# 890   True     young

# %%
#df.drop(columns='age',inplace=True)

# %%
df.groupby('pclass')['fare'].mean()
# Out:
# pclass
# 1    85.675199
# 2    21.889279
# 3    13.566926
# Name: fare, dtype: float64

# %%
df.groupby('sex')['survived'].mean()
# Out:
# sex
# female    0.738832
# male      0.215321
# Name: survived, dtype: float64

# %%
corr=numirical_col.drop(columns=['pclass','survived']).corr()

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm',fmt=".2f")
# Out:
# <Axes: >

# %%
sns.pairplot(data=df,vars=['age','fare'])

# %%
sns.pairplot(df, hue='survived')
